# %% [markdown]
# #### Apply ML algorithms
#
# - Linear Regression
# - Lasso Regression
# - Decision Tree Regressor
# - KNN Regressor
# - RandomForestRegressor
# - Xgboost Regressor
# - Hyperparameter Tuning
# - ANN- Artificial Neural Network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Data\Real-Data\Real_Combine.csv')

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %% [markdown]
# ##### Null value checking....

# %%
df.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    1
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels = False)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    0
# dtype: int64

# %%
x = df.iloc[ : , : -1] # Independent features
y = df.iloc[ : , -1] # Dependednt feature

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967276  0.958892 -0.884383 -0.518870  0.622637  0.326067
# TM      0.967276  1.000000  0.896699 -0.829254 -0.599629  0.598479  0.320116
# Tm      0.958892  0.896699  1.000000 -0.909514 -0.315305  0.560299  0.312904
# SLP    -0.884383 -0.829254 -0.909514  1.000000  0.274196 -0.491842 -0.346130
# H      -0.518870 -0.599629 -0.315305  0.274196  1.000000 -0.475279 -0.399079
# VV      0.622637  0.598479  0.560299 -0.491842 -0.475279  1.000000  0.402884
# V       0.326067  0.320116  0.312904 -0.346130 -0.399079  0.402884  1.000000
# VM      0.287138  0.299508  0.259431 -0.299830 -0.370981  0.347493  0.760777
# PM 2.5 -0.628336 -0.569381 -0.669059  0.615615  0.174658 -0.628621 -0.354799
#
#               VM    PM 2.5
# T       0.287138 -0.628336
# TM      0.299508 -0.569381
# Tm      0.259431 -0.669059
# SLP    -0.299830  0.615615
# H      -0.370981  0.174658
# VV      0.347493 -0.628621
# ...

# %% [markdown]
#  #### Correlation Matrix with Heatmap

# %% [markdown]
# ###### Correlation states how the features are related to each other or the target variable.

# %% [markdown]
# ##### Correlation can be positive (increase in one value of feature increases the value of the target variable) or negative (increase in one value of feature decreases the value of the target variable)

# %% [markdown]
# ##### Heatmap makes it easy to identify which features are most related to the target variable, we will plot heatmap of correlated features using the seaborn library.

# %%
corrmat = df.corr()
top_corrmat_features = corrmat.index
plt.figure(figsize = (10,5))
g = sns.heatmap(df[top_corrmat_features].corr(), annot = True, cmap = 'RdYlGn')

# %%
corrmat.index
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'PM 2.5'], dtype='object')

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# ##### You can get the feature importance of each feature of your dataset by using the feature importance property of the model.

# %% [markdown]
# ##### Feature importance gives you a score for each feature of your data, the higher the score more important or relevant is the feature towards your output variable.

# %% [markdown]
# ##### Feature importance is an inbuilt class that comes with Tree Based Regressor, we will be using Extra Tree Regressor for extracting the top 10 features for the dataset.

# %%
from sklearn.tree import ExtraTreeRegressor

# %%
mod = ExtraTreeRegressor()
mod.fit(x,y)
# Out:
# ExtraTreeRegressor()

# %%
print(mod.feature_importances_)
# Out:
# [0.44457806 0.05429276 0.06431737 0.04805117 0.09146352 0.20269034
#  0.04403403 0.05057275]

# %% [markdown]
# ##### Plot a graph of feature importances for better visualization

# %%
feature_importance = pd.Series(mod.feature_importances_, index = x.columns)
feature_importance.nlargest(5).plot(kind = 'barh')
plt.show()

# %%
sns.distplot(y)

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
x_train, x_test, y_train, y_test = tts(x, y, test_size = 0.2, random_state = 0)
lin_model = LinearRegression()
lin_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lin_model.coef_
# Out:
# array([  1.91864426,   0.60867784,  -6.93208313,   0.72161812,
#         -0.81501081, -47.91320153,  -2.62389632,  -0.15629312])

# %%
lin_model.intercept_
# Out:
# -390.27959590107673

# %%
print('Co-efficient of Determination R^2 on train set...: {}'.format(lin_model.score(x_train, y_train)))
# Out:
# Co-efficient of Determination R^2 on train set...: 0.6023477193124955

# %%
print('Co-efficient of determination R^2 on test set...: {}'.format(lin_model.score(x_test, y_test)))
# Out:
# Co-efficient of determination R^2 on test set...: 0.47814199256563084

# %%
scores = cross_val_score(lin_model, x, y, cv = 6)
scores
# Out:
# array([0.51568169, 0.58516677, 0.56944159, 0.62565782, 0.45505358,
#        0.14762582])

# %%
scores.mean()
# Out:
# 0.48310454662682956

# %% [markdown]
# #### Model Evaluation

# %%
coeff_df = pd.DataFrame(lin_model.coef_, x.columns, columns = ['Co-efficients'])
coeff_df
# Out:
#      Co-efficients
# T         1.918644
# TM        0.608678
# Tm       -6.932083
# SLP       0.721618
# H        -0.815011
# VV      -47.913202
# V        -2.623896
# VM       -0.156293

# %% [markdown]
# ##### Interpreting the coefficients:
#
# i. Holding all other features fixed, a 1 unit increase in T is associated with an decrease of 2.690 in AQI PM2.5 .
# ii. Holding all other features fixed, a 1 unit increase in TM is associated with an increase of 0.46 in AQI PM 2.5 .

# %%
y_predict = lin_model.predict(x_test)

# %%
sns.distplot(y_test - y_predict)

# %%
plt.scatter(y_test, y_predict)

# %% [markdown]
# #### Regression Evaluation Metrics
#
# Here are three common evaluation metrics for regression problems:
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# ##### Comparing these metrics:
#
# 1. MAE is the easiest to understand, because it's the average error.
# 2. MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# 3. RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are loss functions, because we want to minimize them.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pickle

# %%
print('Mean Absolute Error MAE: {}'.format(mean_absolute_error(y_test, y_predict)))
print('Mean Squarred Error MSE: {}'.format(mean_squared_error(y_test, y_predict)))
print('Root Mean Squarred Error RMSE: {}'.format(np.sqrt(mean_squared_error(y_test, y_predict))))
# Out:
# Mean Absolute Error MAE: 41.058724030576464
# Mean Squarred Error MSE: 3140.235984614768
# Root Mean Squarred Error RMSE: 56.03780852794627

# %% [markdown]
# ##### Create a pickle file.

# %%
with open('linear_regression.pkl', 'wb') as f:
    pickle.dump(lin_model, f)

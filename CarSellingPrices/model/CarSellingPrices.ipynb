# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('datasets_car_data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# ...

# %%
df.shape
# Out:
# (301, 9)
# (301, 9)

# %%
df.isnull().any()
# Out:
# Car_Name         False
# Year             False
# Selling_Price    False
# Present_Price    False
# Kms_Driven       False
# Fuel_Type        False
# Seller_Type      False
# Transmission     False
# Owner            False
# dtype: bool
# Car_Name         False
# Year             False
# Selling_Price    False
# Present_Price    False
# Kms_Driven       False
# Fuel_Type        False
# Seller_Type      False
# Transmission     False
# Owner            False
# dtype: bool

# %%
df.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count       301   301.000000     301.000000     301.000000     301.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.627907       4.661296       7.628472   36947.205980
# std         NaN     2.891554       5.082812       8.644115   38886.883882
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.900000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.600000       6.400000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.900000   48767.000000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Seller_Type Transmission       Owner
# ...

# %%
df['Year'].value_counts()
# Out:
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2007     2
# 2003     2
# 2018     1
# 2004     1
# Name: Year, dtype: int64
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2007     2
# 2003     2
# 2018     1
# 2004     1
# Name: Year, dtype: int64

# %%
today = datetime.datetime.now()
year = today.year
year
# Out:
# 2020
# 2020

# %%
df['Year'] = year - df['Year']

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz     6           3.35           5.59       27000    Petrol
# 1      sx4     7           4.75           9.54       43000    Diesel
# 2     ciaz     3           7.25           9.85        6900    Petrol
# 3  wagon r     9           2.85           4.15        5200    Petrol
# 4    swift     6           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz     6           3.35           5.59       27000    Petrol
# 1      sx4     7           4.75           9.54       43000    Diesel
# 2     ciaz     3           7.25           9.85        6900    Petrol
# ...

# %%
print(df['Fuel_Type'].unique())
print(df['Seller_Type'].unique())
print(df['Owner'].unique())
print(df['Transmission'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# [0 1 3]
# ['Manual' 'Automatic']
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# [0 1 3]
# ['Manual' 'Automatic']

# %%
final_df = df.drop(['Car_Name'], axis = 1)

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     6           3.35           5.59       27000    Petrol      Dealer
# 1     7           4.75           9.54       43000    Diesel      Dealer
# 2     3           7.25           9.85        6900    Petrol      Dealer
# 3     9           2.85           4.15        5200    Petrol      Dealer
# 4     6           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     6           3.35           5.59       27000    Petrol      Dealer
# 1     7           4.75           9.54       43000    Diesel      Dealer
# 2     3           7.25           9.85        6900    Petrol      Dealer
# 3     9           2.85           4.15        5200    Petrol      Dealer
# ...

# %%
final_df = pd.get_dummies(final_df, drop_first = True)

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0     6           3.35           5.59       27000      0                 0
# 1     7           4.75           9.54       43000      0                 1
# 2     3           7.25           9.85        6900      0                 0
# 3     9           2.85           4.15        5200      0                 0
# 4     6           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# ...

# %% [markdown]
# #### Finding out the Correlation

# %%
correlations = final_df.corr()
correlations
# Out:
#                             Year  Selling_Price  Present_Price  Kms_Driven  \
# Year                    1.000000      -0.236141       0.047584    0.524342
# Selling_Price          -0.236141       1.000000       0.878983    0.029187
# Present_Price           0.047584       0.878983       1.000000    0.203647
# Kms_Driven              0.524342       0.029187       0.203647    1.000000
# Owner                   0.182104      -0.088344       0.008057    0.089216
# Fuel_Type_Diesel       -0.064315       0.552339       0.473306    0.172515
# Fuel_Type_Petrol        0.059959      -0.540571      -0.465244   -0.172874
# Seller_Type_Individual  0.039896      -0.550724      -0.512030   -0.101419
# Transmission_Manual    -0.000394      -0.367128      -0.348715   -0.162510
#
#                            Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Year                    0.182104         -0.064315          0.059959
# Selling_Price          -0.088344          0.552339         -0.540571
# ...

# %%
sn.pairplot(final_df)

# %%
plt.figure(figsize=(15, 10))
# plot heat map
sn.heatmap(correlations, annot = True, cmap='RdYlGn')

# %%
final_df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0     6           3.35           5.59       27000      0                 0
# 1     7           4.75           9.54       43000      0                 1
# 2     3           7.25           9.85        6900      0                 0
# 3     9           2.85           4.15        5200      0                 0
# 4     6           4.60           6.87       42450      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# ...

# %%
x = final_df.drop(['Selling_Price'], axis = 1)

# %%
x.head()
# Out:
#    Year  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0     6           5.59       27000      0                 0                 1
# 1     7           9.54       43000      0                 1                 0
# 2     3           9.85        6900      0                 0                 1
# 3     9           4.15        5200      0                 0                 1
# 4     6           6.87       42450      0                 1                 0
#
#    Seller_Type_Individual  Transmission_Manual
# 0                       0                    1
# 1                       0                    1
# 2                       0                    1
# 3                       0                    1
# 4                       0                    1
#    Year  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0     6           5.59       27000      0                 0                 1
# ...

# %%
y = final_df['Selling_Price']

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %% [markdown]
# ### Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
fi_model = ExtraTreesRegressor()
fi_model.fit(x,y)
# Out:
# ExtraTreesRegressor()
# ExtraTreesRegressor()

# %%
fi = fi_model.feature_importances_

# %%
print(fi)
# Out:
# [7.81295950e-02 3.77083378e-01 4.04892091e-02 3.67301463e-04
#  2.28961741e-01 9.64359797e-03 1.22603004e-01 1.42722173e-01]
# [7.81295950e-02 3.77083378e-01 4.04892091e-02 3.67301463e-04
#  2.28961741e-01 9.64359797e-03 1.22603004e-01 1.42722173e-01]

# %%
feat_imp = pd.Series(fi, index = x.columns)
feat_imp.nlargest(5).plot(kind ='barh')

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.ensemble import RandomForestRegressor

# %%
train_x, test_x, train_y, test_y = tts(x, y, test_size = 0.2, random_state = 42)

# %%
rnd_mod = RandomForestRegressor()

# %%
n_estimators = [int(x) for x in np.linspace(100, 1200, 12)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

params = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split,
    'min_samples_leaf': min_samples_leaf
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rand = RandomizedSearchCV(rnd_mod, params, n_iter = 10, cv = 5, random_state = 42, \
                          scoring = "neg_mean_squared_error", verbose = 2)
rand.fit(train_x, train_y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.3s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# ...

# %%
y_predict = rand.predict(test_x)

# %%
y_predict
# Out:
# array([ 0.82365,  9.93589,  5.24349,  0.32848,  6.85909,  6.2549 ,
#         1.00892,  0.60638,  0.50786,  6.21145, 10.58562,  0.88314,
#         7.39572,  0.73032,  5.39145,  3.03518,  0.98613, 11.06932,
#         0.62477,  1.43867,  0.53042,  8.65891,  5.8434 ,  2.7409 ,
#         0.53302,  3.54545,  5.2268 ,  3.09165,  1.19913,  1.09891,
#         0.60097,  9.56085,  0.43634,  2.61674,  8.00569,  4.13445,
#         6.13503,  4.7418 ,  3.23658,  5.22585,  4.0388 ,  4.15425,
#         4.8455 ,  0.54572,  6.73011,  0.54752,  7.06467,  6.0184 ,
#         3.14605,  3.721  ,  5.2886 ,  1.38134, 20.96943, 21.00482,
#         6.85145,  8.65392,  5.22119,  9.50689,  2.57714,  7.28718,
#         0.30669])
# array([ 0.82365,  9.93589,  5.24349,  0.32848,  6.85909,  6.2549 ,
#         1.00892,  0.60638,  0.50786,  6.21145, 10.58562,  0.88314,
#         7.39572,  0.73032,  5.39145,  3.03518,  0.98613, 11.06932,
#         0.62477,  1.43867,  0.53042,  8.65891,  5.8434 ,  2.7409 ,
# ...

# %%
sn.distplot(test_y - y_predict)

# %% [markdown]
# #### The difference between the actual value and predicted values are very minimum due to which the graphs are closely aligned. The gaussian distribution looks alike. The below scatter plot looks that there is a linear relationship between the values hence the prediction is too good.

# %%
plt.scatter(test_y, y_predict)

# %%
import pickle

# %%
# f = open('CarSellingPrices_model.pickle', 'wb')
#  pickle.dump(rand, f)
# or you can use the below method

with open('CarSellingPrices_model.pickle', 'wb') as f:
    pickle.dump(rand, f)
